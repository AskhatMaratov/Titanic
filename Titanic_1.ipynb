# %% [markdown]
# # Titanic: Machine Learning from Disaster

# %%
from IPython.display import Image
Image(url= "https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg")
# Out:
# <img src="https://static1.squarespace.com/static/5006453fe4b09ef2252ba068/5095eabce4b06cb305058603/5095eabce4b02d37bef4c24c/1352002236895/100_anniversary_titanic_sinking_by_esai8mellows-d4xbme8.jpg"/>

# %% [markdown]
# # Load a necessary datasets:

# %%
import numpy as np
import pandas as pd

train = pd.read_csv("dataset\\train.csv")
test = pd.read_csv("dataset\\test.csv")

# %% [markdown]
# # The train set info

# %%
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %% [markdown]
# **Data dictionary:**
# * Survived: 0 = No, 1 = Yes
# * Pclass: Ticket class 1 = 1st, 2 = 2nd, 3 = 3rd
# * Sibsp: # of siblings / spouses aboard the Titanic
# * Parch: # of parents / children aboard the Titanic
# * Ticket: Ticket number
# * Cabin: Cabin number
# * Embarked: Port of Embarkation C = Cherbourg, Q = Queenstown, S = Southampton

# %% [markdown]
# Check the shape:

# %%
train.shape
# Out:
# (891, 12)

# %% [markdown]
# Check the info:

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Check the number of NaN values for the train set

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # The test set info

# %%
test.head(50)
# Out:
#     PassengerId  Pclass                                               Name  \
# 0           892       3                                   Kelly, Mr. James
# 1           893       3                   Wilkes, Mrs. James (Ellen Needs)
# 2           894       2                          Myles, Mr. Thomas Francis
# 3           895       3                                   Wirz, Mr. Albert
# 4           896       3       Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5           897       3                         Svensson, Mr. Johan Cervin
# 6           898       3                               Connolly, Miss. Kate
# 7           899       2                       Caldwell, Mr. Albert Francis
# 8           900       3          Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 9           901       3                            Davies, Mr. John Samuel
# 10          902       3                                   Ilieff, Mr. Ylio
# ...

# %% [markdown]
# The shape of the test:

# %%
test.shape
# Out:
# (418, 11)

# %% [markdown]
# Check the info:

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# Check the number of NaN values for the test set

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Visualisation part:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %% [markdown]
# **Bar Chart for Categorical Features**
# * Pclass
# * Sex
# * SibSp ( # of siblings and spouse)
# * Parch ( # of parents and children)
# * Embarked
# * Cabin

# %%
def bar_chart(feature):
    survived = train[train['Survived']==1][feature].value_counts()
    dead = train[train['Survived']==0][feature].value_counts()
    df = pd.DataFrame([survived,dead])
    df.index = ['Survived','Dead']
    df.plot(kind='bar',stacked=True, figsize=(10,5))

# %%
bar_chart('Sex')

# %% [markdown]
# Women have more chance to survive unlike men

# %%
bar_chart('Pclass')

# %% [markdown]
# **1-st class** have more chances to **survive** <br>
# **2-nd class** have more chances to **die** <br>
# **3-rd class** is more likely to **die**

# %%
bar_chart('SibSp')

# %% [markdown]
# A person with **no siblings or spouse** are more likely to **die** <br>
# A person with **one sibling or spouse** are more likely to **survive** <br>
# A person with **more than one sibling or spouse** are more likely to **die**

# %%
bar_chart('Parch')

# %% [markdown]
# A person with **no parents or children** are more likely to **die** <br>
# A person with 1 **parent or child** are more likely to **survive** <br>
# A person with more than 1 **parent or children** are more likely to **die**

# %%
bar_chart('Embarked')

# %% [markdown]
# A person aboarded from **C** slightly more likely **survived** <br>
# A person aboarded from **Q** more likely **dead** <br>
# A person aboarded from **S** more likely **dead**

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Convert feature vectors to numerical representation

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Name feature processing <br>
# Extract titles (Mr., Mrs etc)

# %%
train_and_test = [train, test]

for dataset in train_and_test:
    dataset['Title'] = dataset['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
train['Title'].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Major         2
# Col           2
# Mlle          2
# Mme           1
# Sir           1
# Lady          1
# Ms            1
# Capt          1
# Jonkheer      1
# Don           1
# Countess      1
# Name: Title, dtype: int64

# %%
test['Title'].value_counts()
# Out:
# Mr        240
# Miss       78
# Mrs        72
# Master     21
# Rev         2
# Col         2
# Dr          1
# Ms          1
# Dona        1
# Name: Title, dtype: int64

# %% [markdown]
# **Title map**
# * Mr : 0
# * Miss : 1
# * Mrs: 2
# * Others: 3

# %%
title_mapping = {"Mr": 0, "Miss": 1, "Mrs": 2, 
                 "Master": 3, "Dr": 3, "Rev": 3, "Col": 3, "Major": 3, "Mlle": 3,"Countess": 3,
                 "Ms": 3, "Lady": 3, "Jonkheer": 3, "Don": 3, "Dona" : 3, "Mme": 3,"Capt": 3,"Sir": 3 }
for dataset in train_and_test:
    dataset['Title'] = dataset['Title'].map(title_mapping)

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Title
# 0      0         A/5 21171   7.2500   NaN        S      0
# 1      0          PC 17599  71.2833   C85        C      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S      1
# 3      0            113803  53.1000  C123        S      2
# ...

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Title
# 0  34.5      0      0   330911   7.8292   NaN        Q      0
# 1  47.0      1      0   363272   7.0000   NaN        S      2
# 2  62.0      0      0   240276   9.6875   NaN        Q      0
# 3  27.0      0      0   315154   8.6625   NaN        S      0
# 4  22.0      1      1  3101298  12.2875   NaN        S      2

# %%
bar_chart('Title')

# %% [markdown]
# **Mr** are more likely to **die** <br>
# **Miss** are more likely to **survive** <br>
# **Mrs** are more likely to **survive**

# %% [markdown]
# Delete Name column

# %%
train.drop('Name', axis=1, inplace=True)
test.drop('Name', axis=1, inplace=True)

# %% [markdown]
# # Sex feature processing:

# %% [markdown]
# **Sex map:**
# * Female - 0
# * Male - 1

# %%
sex_mapping = {"male": 0, "female": 1}
for dataset in train_and_test:
    dataset['Sex'] = dataset['Sex'].map(sex_mapping)

# %%
bar_chart('Sex')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0            1         0       3    0  22.0      1      0         A/5 21171
# 1            2         1       1    1  38.0      1      0          PC 17599
# 2            3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3            4         1       1    1  35.0      1      0            113803
# 4            5         0       3    0  35.0      0      0            373450
#
#       Fare Cabin Embarked  Title
# 0   7.2500   NaN        S      0
# 1  71.2833   C85        C      2
# 2   7.9250   NaN        S      1
# 3  53.1000  C123        S      2
# 4   8.0500   NaN        S      0

# %%
test.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch   Ticket     Fare Cabin  \
# 0          892       3    0  34.5      0      0   330911   7.8292   NaN
# 1          893       3    1  47.0      1      0   363272   7.0000   NaN
# 2          894       2    0  62.0      0      0   240276   9.6875   NaN
# 3          895       3    0  27.0      0      0   315154   8.6625   NaN
# 4          896       3    1  22.0      1      1  3101298  12.2875   NaN
#
#   Embarked  Title
# 0        Q      0
# 1        S      2
# 2        Q      0
# 3        S      0
# 4        S      2

# %% [markdown]
# # Age feature processing
# Let's add rounded mean instead of NaN value

# %%
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# 5             6         0       3    0   NaN      0      0            330877
# 6             7         0       1    0  54.0      0      0             17463
# 7             8         0       3    0   2.0      3      1            349909
# 8             9         1       3    1  27.0      0      2            347742
# 9            10         1       2    1  14.0      1      0            237736
# 10           11         1       3    1   4.0      1      1           PP 9549
# ...

# %% [markdown]
# **Fill the missing age with rounded mean age for each title (Mr, Mrs, Miss, Others)**

# %%
train["Age"].fillna(train.groupby("Title")["Age"].transform("mean").round(), inplace=True)
test["Age"].fillna(test.groupby("Title")["Age"].transform("mean").round(), inplace=True)

# %%
train.head(50)
# Out:
#     PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch            Ticket  \
# 0             1         0       3    0  22.0      1      0         A/5 21171
# 1             2         1       1    1  38.0      1      0          PC 17599
# 2             3         1       3    1  26.0      0      0  STON/O2. 3101282
# 3             4         1       1    1  35.0      1      0            113803
# 4             5         0       3    0  35.0      0      0            373450
# 5             6         0       3    0  32.0      0      0            330877
# 6             7         0       1    0  54.0      0      0             17463
# 7             8         0       3    0   2.0      3      1            349909
# 8             9         1       3    1  27.0      0      2            347742
# 9            10         1       2    1  14.0      1      0            237736
# 10           11         1       3    1   4.0      1      1           PP 9549
# ...

# %%
train.groupby("Title")["Age"].transform("mean").round()
# Out:
# 0      32.0
# 1      36.0
# 2      22.0
# 3      36.0
# 4      32.0
#        ...
# 886    20.0
# 887    22.0
# 888    22.0
# 889    32.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
facet = sns.FacetGrid(train, hue = "Survived", aspect = 4)
facet.map(sns.kdeplot, 'Age', shade = True)
facet.set(xlim = (0, train['Age'].max()))
facet.add_legend()
 
plt.show()

# %%
for dataset in train_and_test:
    dataset.loc[ dataset['Age'] <= 16, 'Age'] = 0
    dataset.loc[(dataset['Age'] > 16) & (dataset['Age'] <= 26), 'Age'] = 1
    dataset.loc[(dataset['Age'] > 26) & (dataset['Age'] <= 36), 'Age'] = 2
    dataset.loc[(dataset['Age'] > 36) & (dataset['Age'] <= 62), 'Age'] = 3
    dataset.loc[ dataset['Age'] > 62, 'Age'] = 4

# %%
for dataset in train_and_test:
    dataset.loc[ dataset['Fare'] <= 17, 'Fare'] = 0
    dataset.loc[(dataset['Fare'] > 17) & (dataset['Fare'] <= 30), 'Fare'] = 1
    dataset.loc[(dataset['Fare'] > 30) & (dataset['Fare'] <= 100), 'Fare'] = 2
    dataset.loc[ dataset['Fare'] > 100, 'Fare'] = 3

# %%
# Delete Cabin column because most of values are NaN in test and train set
del train['Cabin']
del test['Cabin']

# %%
train
# Out:
#      PassengerId  Survived  Pclass  Sex  Age  SibSp  Parch            Ticket  \
# 0              1         0       3    0  1.0      1      0         A/5 21171
# 1              2         1       1    1  3.0      1      0          PC 17599
# 2              3         1       3    1  1.0      0      0  STON/O2. 3101282
# 3              4         1       1    1  2.0      1      0            113803
# 4              5         0       3    0  2.0      0      0            373450
# ..           ...       ...     ...  ...  ...    ...    ...               ...
# 886          887         0       2    0  2.0      0      0            211536
# 887          888         1       1    1  1.0      0      0            112053
# 888          889         0       3    1  1.0      1      2        W./C. 6607
# 889          890         1       1    0  1.0      0      0            111369
# 890          891         0       3    0  2.0      0      0            370376
#
#      Fare Embarked  Title
# ...

# %%
# Only 2 values of Embarked column in train set are NaN, so I delete NaN rows
train = train.dropna(subset=['Embarked'])

# %%
test["Fare"].fillna(test.groupby("Pclass")["Fare"].transform("mean").round(), inplace=True)

# %%
train['Embarked'].replace(['S','C','Q'], [0,1,2], inplace=True)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
test['Embarked'].replace(['S','C','Q'], [0,1,2], inplace=True)

# %% [markdown]
# According to the correlation heatmap, we should delete SibSP, Ticket columns

# %%
def correlation_heatmap(train):
    correlations = train.corr()

    fig, ax = plt.subplots(figsize=(10,10))
    sns.heatmap(correlations, vmax=1.0, center=0, fmt='.2f',
                square=True, linewidths=.5, annot=True, cbar_kws={"shrink": .70})
    plt.show();

correlation_heatmap(train)

# %%
features_drop = ['Ticket', 'Parch']
train = train.drop(features_drop, axis=1)
test = test.drop(features_drop, axis=1)
train = train.drop(['PassengerId'], axis=1)

# %%
train_data = train.drop('Survived', axis=1)
target = train['Survived']

train_data.shape, target.shape
# Out:
# ((889, 7), (889,))

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
clf = KNeighborsClassifier(n_neighbors = 13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.70786517 0.71910112 0.85393258 0.7752809  0.84269663 0.82022472
#  0.87640449 0.79775281 0.80898876 0.86363636]

# %%
round(np.mean(score)*100, 2)
# Out:
# 80.66

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.75280899 0.74157303 0.85393258 0.7752809  0.85393258 0.84269663
#  0.87640449 0.78651685 0.85393258 0.88636364]

# %%
round(np.mean(score)*100, 2)
# Out:
# 82.23

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.75280899 0.75280899 0.86516854 0.78651685 0.87640449 0.84269663
#  0.85393258 0.75280899 0.84269663 0.81818182]

# %%
round(np.mean(score)*100, 2)
# Out:
# 81.44

# %%
clf = GaussianNB()
scoring = 'accuracy'
score = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
# Out:
# [0.68539326 0.74157303 0.85393258 0.78651685 0.88764045 0.79775281
#  0.80898876 0.75280899 0.7752809  0.86363636]

# %%
round(np.mean(score)*100,2)
# Out:
# 79.54

# %%
clf = SVC()
clf.fit(train_data, target)

test_data = test.drop("PassengerId", axis=1).copy()
prediction = clf.predict(test_data)

# %%
submission = pd.DataFrame({
        "PassengerId": test["PassengerId"],
        "Survived": prediction
    })

submission.to_csv('submission.csv', index=False)

# %%
list1 = [1, 2, 3, 4]
list2 = [5, 6, 7, 8]
list1 = list2
list1
# Out:
# [5, 6, 7, 8]

# %%
list2
# Out:
# [5, 6, 7, 8]

# %%
list1[2] = 2
list2
# Out:
# [5, 6, 2, 8]

# %%
list1 = ['book_john', 'pencil_askar', 'pen_amin', 'pen_john', 'key_askar',\
        'pen_askar', 'laptop_askar', 'backpack_john', 'car_john']
john_belonging = [bel.split('_')[:1][0] for bel in list1 if bel.split('_')[-1] == 'john']
john_belonging
# Out:
# ['book', 'pen', 'backpack', 'car']

# %%
def name_belonging(name, surname, *belongings):
    print('Name: ' + name + ' ' + surname)
    if (len(belongings) == 0):
        return
    elif (len(belongings) == 1):
        print(belongings[0])
    elif (len(belongings) > 1):
        for item in belongings:
            print(item)
    
    
name_belonging("Amin", "Zollanvari")
#name_belonging(Askar, Muratov)
# Out:
# Name: Amin Zollanvari
